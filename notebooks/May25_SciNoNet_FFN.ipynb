# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import scipy.io
import h5py
import numpy as np
import warnings
import random
import torch.nn.init as init
from scipy.io import savemat
import math
import os
import torch.nn.functional as F
from tqdm import tqdm
from torch.utils.data import TensorDataset, DataLoader

import pandas as pd
warnings.filterwarnings('ignore')

with torch.no_grad():

  torch.cuda.empty_cache()

torch.set_default_dtype(torch.float64)

# %%
# Number of GPU used
warnings.filterwarnings("ignore")
torch.set_default_dtype(torch.float64)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MULTI_GPU = torch.cuda.device_count() > 1
print(f"Running on {DEVICE} with {torch.cuda.device_count()} GPUs")
# Out:
# Running on cuda with 1 GPUs

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="matplotlib.font_manager")

import logging
logging.getLogger("matplotlib.font_manager").setLevel(logging.ERROR)

# %%
# reading the data
# current 50 neighbor data is selected from 72 points
df = pd.read_csv('dataset_50_spatialpoints_partialsignal_mixed_rec_neighbor_50inrange.csv')

# %%
df.isnull().sum()
# Out:
# x    0
# y    0
# z    0
# t    0
# u    0
# v    0
# w    0
# dtype: int64

# %% [markdown]
# # Distribution in Original Data

# %%
def power10_bucket_counts_before_after(df):

    means = df.mean(axis=0)
    stds = df.std(axis=0)
    stds_repl = stds.replace(0, 1.0)
    df_std = (df - means) / stds_repl

    def min_max_exp_from_df(dframe):
        min_exp, max_exp = 100, -100
        for col in dframe.columns:
            vals = np.abs(dframe[col].values.ravel())
            nonzero = vals[vals != 0.0]
            if nonzero.size == 0:
                continue
            lo = int(np.floor(np.log10(nonzero.min())))
            hi = int(np.floor(np.log10(nonzero.max())))
            if lo < min_exp:
                min_exp = lo
            if hi > max_exp:
                max_exp = hi
        return min_exp, max_exp

    min_before, max_before = min_max_exp_from_df(df)
    min_after,  max_after  = min_max_exp_from_df(df_std)

    print("Lowest/Highest exponent BEFORE standardization:", (min_before, max_before))
    print("Lowest/Highest exponent AFTER  standardization:", (min_after, max_after))

    overall_min = min(min_before, min_after)
    overall_max = max(max_before, max_after)
    exps = list(range(overall_min, overall_max + 1))

    index = ["0"] + [f"10^{k}" for k in exps]

    # prepare output columns: for each original col -> col_before, col_after
    out_cols = []
    for c in df.columns:
        out_cols.append(f"{c}_before")
        out_cols.append(f"{c}_after")

    counts_df = pd.DataFrame(0, index=index, columns=out_cols, dtype=int)

    def fill_counts(colname, values, suffix):
        absvals = np.abs(values.ravel())
        zeros = int((absvals == 0.0).sum())
        counts_df.at["0", f"{colname}_{suffix}"] = zeros
        nonzero = absvals[absvals != 0.0]

        for k in exps:
            low = 10.0 ** k
            high = 10.0 ** (k + 1)
            cnt = int(((nonzero >= low) & (nonzero < high)).sum())
            counts_df.at[f"10^{k}", f"{colname}_{suffix}"] = cnt

    for c in df.columns:
        fill_counts(c, df[c].values, "before")
        fill_counts(c, df_std[c].values, "after")

    return counts_df

counts = power10_bucket_counts_before_after(df)
display(counts)
# Out:
# Lowest/Highest exponent BEFORE standardization: (-37, 0)
# Lowest/Highest exponent AFTER  standardization: (-16, 0)
#         x_before  x_after  y_before  y_after  z_before  z_after  t_before  \
# 0              0        0         0        0    150025   150025         0
# 10^-37         0        0         0        0         0        0         0
# 10^-36         0        0         0        0         0        0         0
# 10^-35         0        0         0        0         0        0         0
# 10^-34         0        0         0        0         0        0         0
# 10^-33         0        0         0        0         0        0         0
# 10^-32         0        0         0        0         0        0         0
# 10^-31         0        0         0        0         0        0         0
# 10^-30         0        0         0        0         0        0         0
# 10^-29         0        0         0        0         0        0         0
# 10^-28         0        0         0        0         0        0         0
# 10^-27         0        0         0        0         0        0         0
# 10^-26         0        0         0        0         0        0         0
# 10^-25         0        0         0        0         0        0         0
# 10^-24         0        0         0        0         0        0         0
# 10^-23         0        0         0        0         0        0         0
# 10^-22         0        0         0        0         0        0         0
# 10^-21         0        0         0        0         0        0         0
# 10^-20         0        0         0        0         0        0         0
# 10^-19         0        0         0        0         0        0         0
# 10^-18         0        0         0        0         0        0         0
# 10^-17         0        0         0        0         0        0         0
# 10^-16         0        0         0        0         0        0         0
# 10^-15         0        0         0        0         0        0         0
# 10^-14         0        0         0        0         0        0         0
# 10^-13         0        0         0        0         0        0         0
# 10^-12         0        0         0        0         0        0         0
# 10^-11         0        0         0        0         0        0         0
# 10^-10         0        0         0        0         0        0         0
# 10^-9          0        0         0        0         0        0         0
# 10^-8          0        0         0        0         0        0       225
# 10^-7          0        0         0        0         0        0      2250
# 10^-6          0        0         0        0         0        0     22500
# 10^-5          0        0         0        0         0        0    125050
# 10^-4          0        0         0        0         0        0         0
# 10^-3          0        0         0        0         0        0         0
# 10^-2          0        0         0        0         0        0         0
# 10^-1      27179    84363     12002    83316         0        0         0
# 10^0      122846    65662    138023    66709         0        0         0
#
#         t_after  u_before  u_after  v_before  v_after  w_before  w_after
# 0             0     52165        0     52157        0     52157        0
# 10^-37        0         0        0         0        0        12        0
# 10^-36        0        11        0         0        0        13        0
# 10^-35        0         1        0         0        0         0        0
# 10^-34        0         0        0         0        0         0        0
# 10^-33        0         0        0         0        0         0        0
# 10^-32        0         0        0         0        0         0        0
# 10^-31        0         0        0         0        0         0        0
# 10^-30        0         0        0         0        0         0        0
# 10^-29        0         0        0         0        0         0        0
# 10^-28        0         0        0         0        0         0        0
# 10^-27        0         0        0         0        0         0        0
# 10^-26        0         0        0         0        0         0        0
# 10^-25        0         0        0         0        0         0        0
# 10^-24        0         0        0         0        0         0        0
# 10^-23        0         0        0         0        0         0        0
# 10^-22        0         0        0         0        0         0        0
# 10^-21        0        24        0        14        0        47        0
# 10^-20        0        73        0        61        0       117        0
# 10^-19        0       187        0       158        0       247        0
# 10^-18        0       395        0       325        0       417        0
# 10^-17        0       719        0       586        0       745        0
# 10^-16       25      1226        0      1052        0      1452        0
# 10^-15        0      1778        0      1650        0      1894        0
# 10^-14        0      1987        0      1924        0      2052        0
# 10^-13        0      2151        0      2094        0      2237        0
# 10^-12        0      2350        0      2285        0      2484        0
# 10^-11        0      2621        0      2527        0      2843        0
# 10^-10        0      3013        0      2873        0      3530        0
# 10^-9         0      3850        0      3605        0      6463        0
# 10^-8         0      7918        0      7395        0     16153        0
# 10^-7         0     28488        0     24288        0     34813        0
# 10^-6         0     40051        1     39639        1     22349        1
# 10^-5         0      1017        5      7392       11         0       13
# 10^-4        50         0       67         0    68355         0      129
# 10^-3       800         0    73694         0     6114         0    74300
# 10^-2      7800         0    15342         0    15373         0    16262
# 10^-1     77950         0    35967         0    38345         0    32614
# 10^0      63400         0    24949         0    21826         0    26706

# %% [markdown]
# # Distribution after dropping rows

# %% [markdown]
# # Standardization and distribution after standardization

# %%
# sending the non threshold less
# it has been checked that applying the threshold does not change much of the mean and std value
means = df.mean(axis=0)
print('means of df:', means)
stds = df.std(axis=0)
print('stds of df:', stds)
stds_repl = stds.replace(0, 1.0)
df_std = (df - means) / stds_repl

print(df_std.shape)
# Out:
# means of df: x    1.351208e-01
# y   -3.266979e+00
# z    0.000000e+00
# t    3.001000e-05
# u   -8.994292e-09
# v   -2.380022e-09
# w   -3.288451e-09
# dtype: float64
# stds of df: x    3.473849e+00
# y    1.574698e+00
# z    0.000000e+00
# t    1.732345e-05
# u    2.442149e-06
# v    3.915050e-06
# w    8.030424e-07
# dtype: float64
# (150025, 7)

# %%
df_std.shape
# Out:
# (150025, 7)

# %%
# Save DataFrame to CSV
# this is just to save the std dataset
# from google.colab import files

# csv_filename = "train_data_updated.csv"
# df.to_csv(csv_filename, index=False)

# # Download the file
# files.download(csv_filename)

# %%
df.shape
# Out:
# (150025, 7)

# %%
counts = power10_bucket_counts_before_after(df_std)
display(counts)
# Out:
# Lowest/Highest exponent BEFORE standardization: (-16, 0)
# Lowest/Highest exponent AFTER  standardization: (-17, 0)
#         x_before  x_after  y_before  y_after  z_before  z_after  t_before  \
# 0              0        0         0        0    150025   150025         0
# 10^-17         0        0         0        0         0        0         0
# 10^-16         0        0         0        0         0        0        25
# 10^-15         0        0         0        0         0        0         0
# 10^-14         0        0         0        0         0        0         0
# 10^-13         0        0         0        0         0        0         0
# 10^-12         0        0         0        0         0        0         0
# 10^-11         0        0         0        0         0        0         0
# 10^-10         0        0         0        0         0        0         0
# 10^-9          0        0         0        0         0        0         0
# 10^-8          0        0         0        0         0        0         0
# 10^-7          0        0         0        0         0        0         0
# 10^-6          0        0         0        0         0        0         0
# 10^-5          0        0         0        0         0        0         0
# 10^-4          0        0         0        0         0        0        50
# 10^-3          0        0         0        0         0        0       800
# 10^-2          0        0         0        0         0        0      7800
# 10^-1      84363    84363     83316    83316         0        0     77950
# 10^0       65662    65662     66709    66709         0        0     63400
#
#         t_after  u_before  u_after  v_before  v_after  w_before  w_after
# 0             0         0        0         0        0         0        0
# 10^-17       25         0        0         0        0         0        0
# 10^-16        0         0        0         0        0         0        0
# 10^-15        0         0        0         0        0         0        0
# 10^-14        0         0        0         0        0         0        0
# 10^-13        0         0        0         0        0         0        0
# 10^-12        0         0        0         0        0         0        0
# 10^-11        0         0        0         0        0         0        0
# 10^-10        0         0        0         0        0         0        0
# 10^-9         0         0        0         0        0         0        0
# 10^-8         0         0        0         0        0         0        0
# 10^-7         0         0        0         0        0         0        0
# 10^-6         0         1        1         1        1         1        1
# 10^-5         0         5        5        11       11        13       13
# 10^-4        50        67       67     68355    68355       129      129
# 10^-3       800     73694    73694      6114     6114     74300    74300
# 10^-2      7800     15342    15342     15373    15373     16262    16262
# 10^-1     77950     35967    35967     38345    38345     32614    32614
# 10^0      63400     24949    24949     21826    21826     26706    26706

# %%
df_std.shape
# Out:
# (150025, 7)

# %%
df_std.head()
# Out:
#           x         y    z         t         u         v         w
# 0 -1.622155 -1.418063 -0.0 -1.720211  0.003683  0.000608  0.004095
# 1 -1.622155 -1.418063 -0.0 -1.719634  0.003683  0.000608  0.004095
# 2 -1.622155 -1.418063 -0.0 -1.719057  0.003683  0.000608  0.004095
# 3 -1.622155 -1.418063 -0.0 -1.718480  0.003683  0.000608  0.004095
# 4 -1.622155 -1.418063 -0.0 -1.717902  0.003683  0.000608  0.004095

# %%
def get_unique_spatial_points(df: pd.DataFrame) -> pd.DataFrame:
    """Return unique (x, y) pairs and their count."""
    unique_xy = df[['x', 'y']].drop_duplicates().reset_index(drop=True)
    print(f"Total unique (x, y) pairs: {len(unique_xy)}")
    return unique_xy

# %%
unique_pts = get_unique_spatial_points(df_std)
unique_pts
# Out:
# Total unique (x, y) pairs: 50
#            x         y
# 0  -1.622155 -1.418063
# 1  -1.622155 -0.783020
# 2  -1.622155  1.757148
# 3  -1.334290 -0.783020
# 4  -1.334290 -0.147978
# 5  -1.334290  0.487064
# 6  -1.334290  1.122106
# 7  -1.046425 -1.418063
# 8  -1.046425 -0.783020
# 9  -1.046425 -0.147978
# 10 -1.046425  0.487064
# 11 -1.046425  1.122106
# 12 -0.758560 -0.783020
# 13 -0.758560 -0.147978
# 14 -0.758560  0.487064
# 15 -0.758560  1.122106
# 16 -0.758560  1.757148
# 17 -0.470694 -1.418063
# 18 -0.470694 -0.147978
# 19 -0.470694  0.487064
# 20 -0.470694  1.122106
# 21 -0.182829 -1.418063
# 22 -0.182829 -0.783020
# 23 -0.182829 -0.147978
# 24 -0.182829  0.487064
# 25  0.105036 -1.418063
# 26  0.105036 -0.783020
# 27  0.105036 -0.147978
# 28  0.105036  0.487064
# 29  0.105036  1.122106
# 30  0.392901 -1.418063
# 31  0.392901  0.487064
# 32  0.392901  1.122106
# 33  0.680766 -0.783020
# 34  0.680766 -0.147978
# 35  0.680766  0.487064
# 36  0.680766  1.757148
# 37  0.968632 -1.418063
# 38  0.968632 -0.147978
# 39  0.968632  1.122106
# 40  1.256497 -1.418063
# 41  1.256497 -0.783020
# 42  1.256497 -0.147978
# 43  1.256497  1.122106
# 44  1.544362 -1.418063
# 45  1.544362 -0.783020
# 46  1.544362 -0.147978
# 47  1.544362  0.487064
# 48  1.544362  1.122106
# 49  1.544362  1.757148

# %%
X = df_std[['x', 'y', 'z', 't']].to_numpy()
y = df_std[['u', 'v', 'w']].to_numpy()

X = torch.tensor(X, dtype=torch.float64)
y = torch.tensor(y, dtype=torch.float64)

# %% [markdown]
# # Data Split

# %%
def split_by_spatial_points(X: torch.Tensor, y: torch.Tensor,
                            val_ratio: float = 0.25, test_ratio: float = 0.05,
                            seed: int = 42) -> tuple:
    """Split X, y tensors into train/val/test by unique (x, y) pair ratio."""
    xy = X[:, :2]
    unique_xy = torch.unique(xy, dim=0)
    num_pts = len(unique_xy)

    num_test = max(1, int(num_pts * test_ratio))
    num_val = max(1, int(num_pts * val_ratio))

    rng = np.random.RandomState(seed)
    perm = rng.permutation(num_pts)
    test_ids = perm[:num_test]
    val_ids = perm[num_test:num_test + num_val]
    train_ids = perm[num_test + num_val:]

    test_pts = unique_xy[test_ids]
    val_pts = unique_xy[val_ids]

    is_test = (xy.unsqueeze(1) == test_pts.unsqueeze(0)).all(dim=2).any(dim=1)
    is_val = (xy.unsqueeze(1) == val_pts.unsqueeze(0)).all(dim=2).any(dim=1)
    is_train = ~is_test & ~is_val

    print(f"Unique points -> Train: {len(train_ids)}, Val: {len(val_ids)}, Test: {len(test_ids)}")
    print(f"Rows -> Train: {is_train.sum()}, Val: {is_val.sum()}, Test: {is_test.sum()}")
    return X[is_train], y[is_train], X[is_val], y[is_val], X[is_test], y[is_test]

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_by_spatial_points(X, y, val_ratio=0.25, test_ratio=0.05)
# Out:
# Unique points -> Train: 36, Val: 12, Test: 2
# Rows -> Train: 108018, Val: 36006, Test: 6001

# %%
X_train.shape,  X_val.shape,  X_test.shape, y_train.shape,  y_val.shape,  y_test.shape
# Out:
# (torch.Size([108018, 4]),
#  torch.Size([36006, 4]),
#  torch.Size([6001, 4]),
#  torch.Size([108018, 3]),
#  torch.Size([36006, 3]),
#  torch.Size([6001, 3]))

# %%
BATCH_SIZE = 10000

train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

# %%
def reconstruct(mag_pred, sign_logits):
    signs = 2 * sign_logits - 1.0  # in [-1, 1]
    mag_pred = torch.pow(10, mag_pred)
    output = signs * mag_pred
    return output

# %%
# functions for NN

class SinActivation(nn.Module):
    def forward(self, x): return torch.sin(x)


class FourierFeatures(nn.Module):
    """Fourier Feature Embedding with dispersion-curve-informed frequency ranges.

    Maps raw coordinates x to [sin(2*pi*(a⊙B)*x), cos(2*pi*(a⊙B)*x)],
    where B is a learnable frequency matrix clamped to per-dimension ranges
    derived from the dispersion curve, and a is a trainable amplitude matrix.

    B clamping ranges (applied to standardized inputs):
        x, y : [0, 2]       [rad/mm from dispersion curve]
        z    : fixed at 1
        t    : [20, 200000]  [Hz from dispersion curve]

    Args:
        in_features:    number of input coordinate dims (4 for x,y,z,t)
        num_frequencies: number of random Fourier bases L (output dim = 2L)
    """

    def __init__(self, in_features: int, num_frequencies: int):
        super().__init__()

        B = torch.zeros(in_features, num_frequencies, dtype=torch.float64)
        B[0, :] = torch.empty(num_frequencies, dtype=torch.float64).uniform_(0.0, 2.0)
        B[1, :] = torch.empty(num_frequencies, dtype=torch.float64).uniform_(0.0, 2.0)
        B[2, :] = 1.0
        B[3, :] = torch.empty(num_frequencies, dtype=torch.float64).uniform_(20.0, 200000.0)
        self.B = nn.Parameter(B)

        self.register_buffer(
            "B_min",
            torch.tensor([0.0, 0.0, 1.0, 20.0], dtype=torch.float64).unsqueeze(1)
        )
        self.register_buffer(
            "B_max",
            torch.tensor([2.0, 2.0, 1.0, 200000.0], dtype=torch.float64).unsqueeze(1)
        )

        self.a = nn.Parameter(torch.ones(in_features, num_frequencies, dtype=torch.float64))

    def clamp_B(self):
        """Clamp B to per-dimension ranges. Call after optimizer.step()."""
        with torch.no_grad():
            self.B.clamp_(self.B_min, self.B_max)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x_proj = 2.0 * torch.pi * x @ (self.a * self.B)
        return torch.cat([torch.sin(x_proj), torch.cos(x_proj)], dim=-1)


class TripleHeadNet(nn.Module):
    def __init__(self, sizes, ffn: FourierFeatures):
        super().__init__()
        self.ffn = ffn

        layers = []
        for i in range(len(sizes)-1):
            layers.extend([nn.Linear(sizes[i], sizes[i+1]), SinActivation()])
        self.backbone = nn.Sequential(*layers)

        self.mag_head = nn.Sequential(
            nn.Linear(sizes[-1], 32),
            SinActivation(),
            nn.Linear(32, 16),
            SinActivation(),
            nn.Linear(16, 3),
            nn.Softplus()
        )

        self.sign_head = nn.Sequential(
                nn.Linear(sizes[-1], 32),
                SinActivation(),
                nn.Linear(32, 3),
                nn.Sigmoid()
            )

        self.phys_mag_head = nn.Sequential(
                nn.Linear(sizes[-1], 32),
                SinActivation(),
                nn.Linear(32, 16),
                SinActivation(),
                nn.Linear(16, 4),
                SinActivation()
            )
        self.phys_sign_head = nn.Sequential(
                nn.Linear(sizes[-1], 32),
                nn.ReLU(),
                nn.Linear(32, 4),
                nn.Sigmoid()
            )

        # trainable weightage factors for PDE loss
        self.raw_lambda_1 = nn.Parameter(torch.tensor([2.0], dtype=torch.float64))
        self.raw_lambda_2 = nn.Parameter(torch.tensor([200.0], dtype=torch.float64))
        self.raw_lambda_3 = nn.Parameter(torch.tensor([2.0], dtype=torch.float64))

        # SIREN-style init for sine-activated layers (fixes dead-code bug in original)
        self.apply(TripleHeadNet._init_weights)

    @staticmethod
    def _init_weights(m):
        """SIREN hidden-layer init: W ~ U(-sqrt(6/fan_in), sqrt(6/fan_in)).

        Correct for layers followed by sin activation. Adequate for the few
        layers followed by ReLU/Sigmoid/Softplus in the heads.
        """
        if isinstance(m, nn.Linear):
            fan_in = m.weight.size(1)
            bound = np.sqrt(6.0 / fan_in)
            nn.init.uniform_(m.weight, -bound, bound)
            if m.bias is not None:
                nn.init.zeros_(m.bias)

    def get_lambda(self):
      lam1 = F.softplus(self.raw_lambda_1) + 1e-6
      lam2 = F.softplus(self.raw_lambda_2) + 1e-6
      lam3 = F.softplus(self.raw_lambda_3) + 1e-6

      # using sigmoid
      lam1 = 1 / lam1
      lam2 = 1 / lam2
      lam3 = 1 / lam3
      return lam1, lam2, lam3


    def forward(self, x):
        x_embed = self.ffn(x)
        f = self.backbone(x_embed)

        # Data predictions
        mag_out = self.mag_head(f)
        sign_out = self.sign_head(f)

        # Physics predictions
        phys_mag = self.phys_mag_head(f)
        phys_sign = self.phys_sign_head(f)

        return mag_out, sign_out, phys_mag, phys_sign

# %%
def compute_physics(phys_mag, phys_sign, X):

    phi_zi = reconstruct(phys_mag, phys_sign)
    phi, zi1, zi2, zi3 = phi_zi[:, 0], phi_zi[:, 1], phi_zi[:, 2], phi_zi[:, 3]
    grads_phi = torch.autograd.grad(phi, X, grad_outputs=torch.ones_like(phi), create_graph=True)[0]
    grads_zi1  = torch.autograd.grad(zi1, X, grad_outputs=torch.ones_like(zi1),  create_graph=True)[0]
    grads_zi2  = torch.autograd.grad(zi2, X, grad_outputs=torch.ones_like(zi2),  create_graph=True)[0]
    grads_zi3  = torch.autograd.grad(zi3, X, grad_outputs=torch.ones_like(zi3),  create_graph=True)[0]

    d2phi_dx2 = torch.autograd.grad(grads_phi[:, 0], X, grad_outputs=torch.ones_like(grads_phi[:, 0]), create_graph=True)[0][:, 0]
    d2phi_dy2 = torch.autograd.grad(grads_phi[:, 1], X, grad_outputs=torch.ones_like(grads_phi[:, 1]), create_graph=True)[0][:, 1]
    #d2phi_dz2 = torch.autograd.grad(grads_phi[:, 2], X, grad_outputs=torch.ones_like(grads_phi[:, 2]), create_graph=True)[0][:, 2]
    d2phi_dt2 = torch.autograd.grad(grads_phi[:, 3], X, grad_outputs=torch.ones_like(grads_phi[:, 3]), create_graph=True)[0][:, 3]

    d2zi1_dx2  = torch.autograd.grad(grads_zi1[:, 0], X, grad_outputs=torch.ones_like(grads_zi1[:, 0]), create_graph=True)[0][:, 0]
    d2zi1_dy2  = torch.autograd.grad(grads_zi1[:, 1], X, grad_outputs=torch.ones_like(grads_zi1[:, 1]), create_graph=True)[0][:, 1]
    #d2zi1_dz2  = torch.autograd.grad(grads_zi1[:, 2], X, grad_outputs=torch.ones_like(grads_zi1[:, 2]), create_graph=True)[0][:, 2]
    d2zi1_dt2  = torch.autograd.grad(grads_zi1[:, 3], X, grad_outputs=torch.ones_like(grads_zi1[:, 3]), create_graph=True)[0][:, 3]

    d2zi2_dx2  = torch.autograd.grad(grads_zi2[:, 0], X, grad_outputs=torch.ones_like(grads_zi2[:, 0]), create_graph=True)[0][:, 0]
    d2zi2_dy2  = torch.autograd.grad(grads_zi2[:, 1], X, grad_outputs=torch.ones_like(grads_zi2[:, 1]), create_graph=True)[0][:, 1]
    #d2zi2_dz2  = torch.autograd.grad(grads_zi2[:, 2], X, grad_outputs=torch.ones_like(grads_zi2[:, 2]), create_graph=True)[0][:, 2]
    d2zi2_dt2  = torch.autograd.grad(grads_zi2[:, 3], X, grad_outputs=torch.ones_like(grads_zi2[:, 3]), create_graph=True)[0][:, 3]

    d2zi3_dx2  = torch.autograd.grad(grads_zi3[:, 0], X, grad_outputs=torch.ones_like(grads_zi3[:, 0]), create_graph=True)[0][:, 0]
    d2zi3_dy2  = torch.autograd.grad(grads_zi3[:, 1], X, grad_outputs=torch.ones_like(grads_zi3[:, 1]), create_graph=True)[0][:, 1]
    #d2zi3_dz2  = torch.autograd.grad(grads_zi3[:, 2], X, grad_outputs=torch.ones_like(grads_zi3[:, 2]), create_graph=True)[0][:, 2]
    d2zi3_dt2  = torch.autograd.grad(grads_zi3[:, 3], X, grad_outputs=torch.ones_like(grads_zi3[:, 3]), create_graph=True)[0][:, 3]

    cp2, cs2 = 6.3**2, 3.2**2

    f_phi = cp2 * (d2phi_dx2 + d2phi_dy2) - d2phi_dt2
    f_zi1  = cs2 * (d2zi1_dx2 + d2zi1_dy2) - d2zi1_dt2
    f_zi2  = cs2 * (d2zi2_dx2 + d2zi2_dy2) - d2zi2_dt2
    f_zi3  = cs2 * (d2zi3_dx2 + d2zi3_dy2) - d2zi3_dt2

    u_calc = grads_phi[:, 0] + grads_zi3[:, 1]
    v_calc = - grads_zi3[:, 0] + grads_phi[:, 1]
    w_calc = - grads_zi2[:, 0] + grads_zi1[:, 1]

    return f_phi, f_zi1, f_zi2, f_zi3, u_calc, v_calc, w_calc

# %%
def train(model, train_loader, val_loader, optimizer, scheduler, epochs):
    import torch
    import torch.nn as nn
    import torch.nn.functional as F

    # histories (train, averaged per epoch)
    total_losses, data_losses, phys_losses, phys_data_losses = [], [], [], []
    # histories (val, averaged per epoch)
    val_total_losses, val_data_losses, val_phys_losses, val_phys_data_losses = [], [], [], []
    # lambda histories (epoch-averaged from train)
    lam1_hist, lam2_hist, lam3_hist = [], [], []

    best_loss = float("inf")
    epochs_no_improve = 0
    best_state = None

    mse = nn.MSELoss()

    for epoch in range(epochs):
        # --------------------
        # TRAIN
        # --------------------
        model.train()
        tr_sum_total = tr_sum_data = tr_sum_phys = tr_sum_phys_data = 0.0
        lam1_sum = lam2_sum = lam3_sum = 0.0
        n_train_batches = 0

        for Xb, Yb in train_loader:
            Xb, Yb = Xb.to(DEVICE), Yb.to(DEVICE)
            Xb.requires_grad_(True)

            optimizer.zero_grad()

            # forward
            mag_out, sign_out, phys_mag, phys_sign = model(Xb)
            preds = reconstruct(mag_out, sign_out)
            f_phi, f_zi1, f_zi2, f_zi3, u_calc, v_calc, w_calc = compute_physics(phys_mag, phys_sign, Xb)

            # losses
            data_loss = mse(preds, Yb)
            phys_data_loss = F.smooth_l1_loss(u_calc, Yb[:, 0]) + F.smooth_l1_loss(v_calc, Yb[:, 1]) + F.smooth_l1_loss(w_calc, Yb[:, 2])
            phys_loss = (
                F.smooth_l1_loss(f_phi, torch.zeros_like(f_phi))
                + F.smooth_l1_loss(f_zi1, torch.zeros_like(f_zi1))
                + F.smooth_l1_loss(f_zi2, torch.zeros_like(f_zi2))
                + F.smooth_l1_loss(f_zi3, torch.zeros_like(f_zi3))
            )

            # lambdas (handle DP)
            root = model.module if isinstance(model, nn.DataParallel) else model
            lam1, lam2, lam3 = root.get_lambda()

            # total loss with barrier
            loss = (
                lam1 * data_loss + lam2 * phys_loss + lam3 * phys_data_loss
                - torch.log(lam1) - torch.log(lam2) - torch.log(lam3)
            )

            # total loss
            #loss = data_loss + phys_data_loss + 1000* phys_loss

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            root = model.module if isinstance(model, nn.DataParallel) else model
            root.ffn.clamp_B()

            # accumulators (sums over batches)
            tr_sum_total += float(loss.item())
            tr_sum_data += float(data_loss.item())
            tr_sum_phys += float(phys_loss.item())
            tr_sum_phys_data += float(phys_data_loss.item())

            lam1_sum += float(lam1.item())
            lam2_sum += float(lam2.item())
            lam3_sum += float(lam3.item())
            n_train_batches += 1

        # epoch-avg train losses
        denom_tr = max(1, n_train_batches)
        epoch_total_avg = tr_sum_total / denom_tr
        epoch_data_avg  = tr_sum_data / denom_tr
        epoch_phys_avg  = tr_sum_phys / denom_tr
        epoch_pdata_avg = tr_sum_phys_data / denom_tr

        total_losses.append(epoch_total_avg)
        data_losses.append(epoch_data_avg)
        phys_losses.append(epoch_phys_avg)
        phys_data_losses.append(epoch_pdata_avg)

        # epoch-avg lambdas (train)
        lam1_epoch = lam1_sum / denom_tr
        lam2_epoch = lam2_sum / denom_tr
        lam3_epoch = lam3_sum / denom_tr
        lam1_hist.append(lam1_epoch)
        lam2_hist.append(lam2_epoch)
        lam3_hist.append(lam3_epoch)

        # --------------------
        # VALIDATION
        # --------------------
        model.eval()
        val_sum_total = val_sum_data = val_sum_phys = val_sum_phys_data = 0.0
        n_val_batches = 0

        # IMPORTANT: do NOT disable grad here; compute_physics needs autograd
        for Xv, Yv in val_loader:
          Xv, Yv = Xv.to(DEVICE), Yv.to(DEVICE)
          # allow autograd wrt inputs for physics residuals
          Xv = Xv.clone().detach().requires_grad_(True)

          # forward with grad enabled so autograd can flow to Xv
          mag_out, sign_out, phys_mag, phys_sign = model(Xv)
          preds = reconstruct(mag_out, sign_out)
          f_phi, f_zi1, f_zi2, f_zi3, u_calc, v_calc, w_calc = compute_physics(phys_mag, phys_sign, Xv)

          # val losses (no backward)
          v_data_loss = mse(preds, Yv)
          v_phys_data_loss = F.smooth_l1_loss(u_calc, Yv[:, 0]) + F.smooth_l1_loss(v_calc, Yv[:, 1])
          v_phys_loss = (
              F.smooth_l1_loss(f_phi, torch.zeros_like(f_phi))
              + F.smooth_l1_loss(f_zi1, torch.zeros_like(f_zi1))
              + F.smooth_l1_loss(f_zi2, torch.zeros_like(f_zi2))
              + F.smooth_l1_loss(f_zi3, torch.zeros_like(f_zi3))
          )

          # use current lambdas but detach them to avoid tracking grads
          root = model.module if isinstance(model, nn.DataParallel) else model
          lam1, lam2, lam3 = root.get_lambda()
          lam1 = lam1.detach()
          lam2 = lam2.detach()
          lam3 = lam3.detach()

          v_loss = (
              lam1 * v_data_loss + lam2 * v_phys_loss + lam3 * v_phys_data_loss
              - torch.log(lam1) - torch.log(lam2) - torch.log(lam3)
          )

          #v_loss = v_data_loss + v_phys_data_loss + 1000* v_phys_loss

          val_sum_total += float(v_loss.item())
          val_sum_data += float(v_data_loss.item())
          val_sum_phys += float(v_phys_loss.item())
          val_sum_phys_data += float(v_phys_data_loss.item())
          n_val_batches += 1

        # epoch-avg val losses
        denom_val = max(1, n_val_batches)
        v_epoch_total_avg = val_sum_total / denom_val
        v_epoch_data_avg  = val_sum_data / denom_val
        v_epoch_phys_avg  = val_sum_phys / denom_val
        v_epoch_pdata_avg = val_sum_phys_data / denom_val

        val_total_losses.append(v_epoch_total_avg)
        val_data_losses.append(v_epoch_data_avg)
        val_phys_losses.append(v_epoch_phys_avg)
        val_phys_data_losses.append(v_epoch_pdata_avg)

        # --------------------
        # SCHEDULER (on avg train total)
        # --------------------
        scheduler.step(epoch_total_avg)

        # --------------------
        # PRINT (averages)
        # --------------------
        print(
            f"Epoch {epoch+1:03d}: "
            f"Train: Total={epoch_total_avg:.3e}, Data={epoch_data_avg:.3e}, Phys={epoch_phys_avg:.3e}, PhysData={epoch_pdata_avg:.3e} | "
            f"Val: Total={v_epoch_total_avg:.3e}, Data={v_epoch_data_avg:.3e}, Phys={v_epoch_phys_avg:.3e}, PhysData={v_epoch_pdata_avg:.3e} | "
            f"Lambda: λ1={lam1_epoch:.3e}, λ2={lam2_epoch:.3e}, λ3={lam3_epoch:.3e}"
        )

        # --------------------
        # --------------------
        # EARLY STOP (val loss > train loss for 20 consecutive epochs)
        # --------------------
        if v_epoch_total_avg > epoch_total_avg:
            epochs_no_improve += 1
        else:
            epochs_no_improve = 0

        if epochs_no_improve >= 500:
            print(f"Early stopping at epoch {epoch+1} (val loss > train loss for 20 consecutive epochs).")
            break

    # return averaged histories
    return (
        total_losses, data_losses, phys_losses, phys_data_losses,
        val_total_losses, val_data_losses, val_phys_losses, val_phys_data_losses,
        lam1_hist, lam2_hist, lam3_hist
    )

# %%
# Build model with dispersion-curve-informed Fourier features
NUM_FREQ = 32
ffn = FourierFeatures(in_features=4, num_frequencies=NUM_FREQ)

# sizes[0] = 2 * NUM_FREQ = 64 (FFE output dimension)
model = TripleHeadNet([64, 64, 64, 128, 256, 512, 256], ffn=ffn)
if MULTI_GPU:
    model = nn.DataParallel(model)
model.to(DEVICE)
# Out:
# TripleHeadNet(
#   (ffn): FourierFeatures()
#   (backbone): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): SinActivation()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): SinActivation()
#     (4): Linear(in_features=64, out_features=128, bias=True)
#     (5): SinActivation()
#     (6): Linear(in_features=128, out_features=256, bias=True)
#     (7): SinActivation()
#     (8): Linear(in_features=256, out_features=512, bias=True)
#     (9): SinActivation()
#     (10): Linear(in_features=512, out_features=256, bias=True)
#     (11): SinActivation()
#   )
#   (mag_head): Sequential(
#     (0): Linear(in_features=256, out_features=32, bias=True)
#     (1): SinActivation()
#     (2): Linear(in_features=32, out_features=16, bias=True)
#     (3): SinActivation()
#     (4): Linear(in_features=16, out_features=3, bias=True)
#     (5): Softplus(beta=1.0, threshold=20.0)
#   )
#   (sign_head): Sequential(
#     (0): Linear(in_features=256, out_features=32, bias=True)
#     (1): SinActivation()
#     (2): Linear(in_features=32, out_features=3, bias=True)
#     (3): Sigmoid()
#   )
#   (phys_mag_head): Sequential(
#     (0): Linear(in_features=256, out_features=32, bias=True)
#     (1): SinActivation()
#     (2): Linear(in_features=32, out_features=16, bias=True)
#     (3): SinActivation()
#     (4): Linear(in_features=16, out_features=4, bias=True)
#     (5): SinActivation()
#   )
#   (phys_sign_head): Sequential(
#     (0): Linear(in_features=256, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=4, bias=True)
#     (3): Sigmoid()
#   )
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=8)

# %%
import time

start_time = time.time()

(
    tr_tot, tr_data, tr_phys, tr_physdata,
    va_tot, va_data, va_phys, va_physdata,
    lam1_hist, lam2_hist, lam3_hist
) = train(model, train_loader, val_loader, optimizer, scheduler, epochs= 120)

end_time = time.time()
total_time = end_time - start_time

# Print the total training time in one line
print(f"\nTotal training time: {total_time/60:.2f} minutes ({total_time:.2f} seconds)")
# Out:
# Epoch 001: Train: Total=7.220e+10, Data=1.192e+03, Phys=1.444e+13, PhysData=3.644e+01 | Val: Total=2.253e+10, Data=9.204e+02, Phys=4.507e+12, PhysData=8.341e+00 | Lambda: λ1=4.702e-01, λ2=5.000e-03, λ3=4.702e-01
# Epoch 002: Train: Total=9.418e+09, Data=1.171e+03, Phys=1.884e+12, PhysData=4.993e+00 | Val: Total=1.690e+09, Data=7.852e+02, Phys=3.381e+11, PhysData=7.275e-01 | Lambda: λ1=4.702e-01, λ2=5.000e-03, λ3=4.702e-01
# Epoch 003: Train: Total=9.941e+08, Data=9.533e+02, Phys=1.988e+11, PhysData=1.083e+00 | Val: Total=5.580e+08, Data=7.567e+02, Phys=1.116e+11, PhysData=5.399e-01 | Lambda: λ1=4.702e-01, λ2=4.999e-03, λ3=4.702e-01
# Epoch 004: Train: Total=3.708e+08, Data=5.370e+02, Phys=7.417e+10, PhysData=9.693e-01 | Val: Total=1.987e+08, Data=2.875e+02, Phys=3.974e+10, PhysData=5.054e-01 | Lambda: λ1=4.702e-01, λ2=4.999e-03, λ3=4.702e-01
# Epoch 005: Train: Total=1.201e+08, Data=1.489e+02, Phys=2.403e+10, PhysData=9.464e-01 | Val: Total=5.691e+07, Data=4.651e+01, Phys=1.138e+10, PhysData=4.990e-01 | Lambda: λ1=4.702e-01, λ2=4.999e-03, λ3=4.702e-01
# Epoch 006: Train: Total=3.538e+07, Data=2.754e+01, Phys=7.079e+09, PhysData=9.421e-01 | Val: Total=1.899e+07, Data=1.379e+01, Phys=3.800e+09, PhysData=4.986e-01 | Lambda: λ1=4.702e-01, λ2=4.998e-03, λ3=4.702e-01
# Epoch 007: Train: Total=1.452e+07, Data=1.048e+01, Phys=2.905e+09, PhysData=9.421e-01 | Val: Total=8.907e+06, Data=7.524e+00, Phys=1.782e+09, PhysData=4.985e-01 | Lambda: λ1=4.702e-01, λ2=4.998e-03, λ3=4.702e-01
# Epoch 008: Train: Total=7.549e+06, Data=6.929e+00, Phys=1.511e+09, PhysData=9.412e-01 | Val: Total=5.391e+06, Data=6.879e+00, Phys=1.079e+09, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.998e-03, λ3=4.702e-01
# Epoch 009: Train: Total=4.160e+06, Data=6.232e+00, Phys=8.324e+08, PhysData=9.421e-01 | Val: Total=3.499e+06, Data=5.450e+00, Phys=7.003e+08, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.997e-03, λ3=4.702e-01
# Epoch 010: Train: Total=3.179e+06, Data=6.025e+00, Phys=6.362e+08, PhysData=9.422e-01 | Val: Total=3.152e+06, Data=6.588e+00, Phys=6.309e+08, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.997e-03, λ3=4.702e-01
# Epoch 011: Train: Total=2.548e+06, Data=6.299e+00, Phys=5.100e+08, PhysData=9.430e-01 | Val: Total=2.163e+06, Data=6.829e+00, Phys=4.329e+08, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.997e-03, λ3=4.702e-01
# Epoch 012: Train: Total=1.786e+06, Data=8.451e+00, Phys=3.575e+08, PhysData=9.418e-01 | Val: Total=1.722e+06, Data=9.138e+00, Phys=3.447e+08, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.996e-03, λ3=4.702e-01
# Epoch 013: Train: Total=1.303e+06, Data=9.781e+00, Phys=2.607e+08, PhysData=9.418e-01 | Val: Total=1.529e+06, Data=9.243e+00, Phys=3.061e+08, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.996e-03, λ3=4.702e-01
# Epoch 014: Train: Total=9.769e+05, Data=1.014e+01, Phys=1.956e+08, PhysData=9.427e-01 | Val: Total=5.989e+05, Data=1.027e+01, Phys=1.199e+08, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.996e-03, λ3=4.702e-01
# Epoch 015: Train: Total=6.085e+05, Data=9.121e+00, Phys=1.218e+08, PhysData=9.421e-01 | Val: Total=6.741e+05, Data=8.101e+00, Phys=1.350e+08, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.995e-03, λ3=4.702e-01
# Epoch 016: Train: Total=4.989e+05, Data=8.529e+00, Phys=9.989e+07, PhysData=9.419e-01 | Val: Total=3.630e+05, Data=8.818e+00, Phys=7.268e+07, PhysData=4.985e-01 | Lambda: λ1=4.700e-01, λ2=4.995e-03, λ3=4.702e-01
# Epoch 017: Train: Total=4.648e+05, Data=8.311e+00, Phys=9.307e+07, PhysData=9.424e-01 | Val: Total=3.409e+05, Data=8.133e+00, Phys=6.825e+07, PhysData=4.985e-01 | Lambda: λ1=4.700e-01, λ2=4.995e-03, λ3=4.702e-01
# Epoch 018: Train: Total=1.131e+06, Data=9.141e+00, Phys=2.264e+08, PhysData=9.424e-01 | Val: Total=1.069e+06, Data=1.074e+01, Phys=2.140e+08, PhysData=4.985e-01 | Lambda: λ1=4.699e-01, λ2=4.994e-03, λ3=4.702e-01
# Epoch 019: Train: Total=7.810e+05, Data=1.018e+01, Phys=1.564e+08, PhysData=9.418e-01 | Val: Total=4.742e+05, Data=7.181e+00, Phys=9.496e+07, PhysData=4.985e-01 | Lambda: λ1=4.698e-01, λ2=4.994e-03, λ3=4.702e-01
# Epoch 020: Train: Total=3.446e+05, Data=7.794e+00, Phys=6.901e+07, PhysData=9.421e-01 | Val: Total=3.702e+05, Data=9.626e+00, Phys=7.414e+07, PhysData=4.985e-01 | Lambda: λ1=4.698e-01, λ2=4.994e-03, λ3=4.702e-01
# Epoch 021: Train: Total=3.287e+05, Data=6.579e+00, Phys=6.583e+07, PhysData=9.419e-01 | Val: Total=2.667e+05, Data=1.471e+00, Phys=5.341e+07, PhysData=4.985e-01 | Lambda: λ1=4.697e-01, λ2=4.993e-03, λ3=4.702e-01
# Epoch 022: Train: Total=3.367e+05, Data=1.421e+00, Phys=6.743e+07, PhysData=9.419e-01 | Val: Total=3.553e+05, Data=1.122e+00, Phys=7.117e+07, PhysData=4.985e-01 | Lambda: λ1=4.697e-01, λ2=4.993e-03, λ3=4.703e-01
# Epoch 023: Train: Total=2.452e+05, Data=1.535e+00, Phys=4.911e+07, PhysData=9.414e-01 | Val: Total=2.016e+05, Data=1.575e+00, Phys=4.038e+07, PhysData=4.985e-01 | Lambda: λ1=4.697e-01, λ2=4.993e-03, λ3=4.703e-01
# Epoch 024: Train: Total=4.699e+05, Data=1.644e+00, Phys=9.412e+07, PhysData=9.420e-01 | Val: Total=3.489e+05, Data=1.277e+00, Phys=6.988e+07, PhysData=4.985e-01 | Lambda: λ1=4.697e-01, λ2=4.993e-03, λ3=4.703e-01
# Epoch 025: Train: Total=3.198e+05, Data=1.415e+00, Phys=6.407e+07, PhysData=9.422e-01 | Val: Total=1.383e+05, Data=1.205e+00, Phys=2.770e+07, PhysData=4.985e-01 | Lambda: λ1=4.697e-01, λ2=4.992e-03, λ3=4.703e-01
# Epoch 026: Train: Total=1.665e+05, Data=1.267e+00, Phys=3.335e+07, PhysData=9.416e-01 | Val: Total=1.164e+05, Data=1.024e+00, Phys=2.332e+07, PhysData=4.985e-01 | Lambda: λ1=4.697e-01, λ2=4.992e-03, λ3=4.703e-01
# Epoch 027: Train: Total=1.290e+05, Data=1.134e+00, Phys=2.584e+07, PhysData=9.428e-01 | Val: Total=1.309e+05, Data=9.200e-01, Phys=2.623e+07, PhysData=4.985e-01 | Lambda: λ1=4.697e-01, λ2=4.992e-03, λ3=4.703e-01
# Epoch 028: Train: Total=1.514e+05, Data=1.080e+00, Phys=3.033e+07, PhysData=9.425e-01 | Val: Total=1.423e+05, Data=8.996e-01, Phys=2.851e+07, PhysData=4.985e-01 | Lambda: λ1=4.698e-01, λ2=4.992e-03, λ3=4.704e-01
# Epoch 029: Train: Total=1.573e+05, Data=1.087e+00, Phys=3.151e+07, PhysData=9.412e-01 | Val: Total=1.669e+05, Data=1.029e+00, Phys=3.344e+07, PhysData=4.985e-01 | Lambda: λ1=4.698e-01, λ2=4.991e-03, λ3=4.704e-01
# Epoch 030: Train: Total=9.224e+04, Data=1.484e+00, Phys=1.848e+07, PhysData=9.419e-01 | Val: Total=9.251e+04, Data=1.350e+00, Phys=1.853e+07, PhysData=4.985e-01 | Lambda: λ1=4.698e-01, λ2=4.991e-03, λ3=4.705e-01
# Epoch 031: Train: Total=3.943e+04, Data=1.324e+00, Phys=7.899e+06, PhysData=9.417e-01 | Val: Total=4.836e+04, Data=1.029e+00, Phys=9.689e+06, PhysData=4.985e-01 | Lambda: λ1=4.699e-01, λ2=4.991e-03, λ3=4.705e-01
# Epoch 032: Train: Total=5.854e+04, Data=1.169e+00, Phys=1.173e+07, PhysData=9.423e-01 | Val: Total=8.598e+04, Data=9.781e-01, Phys=1.723e+07, PhysData=4.985e-01 | Lambda: λ1=4.699e-01, λ2=4.991e-03, λ3=4.706e-01
# Epoch 033: Train: Total=1.341e+05, Data=1.134e+00, Phys=2.686e+07, PhysData=9.420e-01 | Val: Total=1.766e+05, Data=1.051e+00, Phys=3.538e+07, PhysData=4.985e-01 | Lambda: λ1=4.700e-01, λ2=4.990e-03, λ3=4.707e-01
# Epoch 034: Train: Total=9.493e+04, Data=1.444e+00, Phys=1.902e+07, PhysData=9.425e-01 | Val: Total=1.696e+05, Data=1.539e+00, Phys=3.400e+07, PhysData=4.985e-01 | Lambda: λ1=4.700e-01, λ2=4.990e-03, λ3=4.708e-01
# Epoch 035: Train: Total=4.065e+05, Data=1.890e+00, Phys=8.146e+07, PhysData=9.420e-01 | Val: Total=2.187e+05, Data=1.992e+00, Phys=4.382e+07, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.990e-03, λ3=4.708e-01
# Epoch 036: Train: Total=2.291e+05, Data=2.584e+00, Phys=4.592e+07, PhysData=9.425e-01 | Val: Total=2.345e+05, Data=3.211e+00, Phys=4.700e+07, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.990e-03, λ3=4.708e-01
# Epoch 037: Train: Total=2.315e+05, Data=2.328e+00, Phys=4.640e+07, PhysData=9.428e-01 | Val: Total=2.622e+05, Data=1.641e+00, Phys=5.255e+07, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.989e-03, λ3=4.709e-01
# Epoch 038: Train: Total=2.181e+05, Data=1.614e+00, Phys=4.371e+07, PhysData=9.419e-01 | Val: Total=1.059e+05, Data=1.364e+00, Phys=2.123e+07, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.989e-03, λ3=4.709e-01
# Epoch 039: Train: Total=1.786e+05, Data=1.439e+00, Phys=3.580e+07, PhysData=9.425e-01 | Val: Total=1.088e+05, Data=1.112e+00, Phys=2.180e+07, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.989e-03, λ3=4.709e-01
# Epoch 040: Train: Total=1.495e+05, Data=1.345e+00, Phys=2.997e+07, PhysData=9.412e-01 | Val: Total=8.778e+04, Data=1.237e+00, Phys=1.759e+07, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.989e-03, λ3=4.709e-01
# Epoch 041: Train: Total=6.304e+04, Data=1.373e+00, Phys=1.264e+07, PhysData=9.419e-01 | Val: Total=9.518e+04, Data=1.125e+00, Phys=1.908e+07, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.988e-03, λ3=4.710e-01
# Epoch 042: Train: Total=3.952e+04, Data=1.334e+00, Phys=7.922e+06, PhysData=9.420e-01 | Val: Total=4.282e+04, Data=1.129e+00, Phys=8.583e+06, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.988e-03, λ3=4.710e-01
# Epoch 043: Train: Total=2.623e+04, Data=1.293e+00, Phys=5.256e+06, PhysData=9.417e-01 | Val: Total=3.481e+04, Data=1.096e+00, Phys=6.977e+06, PhysData=4.985e-01 | Lambda: λ1=4.701e-01, λ2=4.988e-03, λ3=4.710e-01
# Epoch 044: Train: Total=2.175e+04, Data=1.206e+00, Phys=4.359e+06, PhysData=9.421e-01 | Val: Total=1.124e+04, Data=9.692e-01, Phys=2.252e+06, PhysData=4.985e-01 | Lambda: λ1=4.702e-01, λ2=4.988e-03, λ3=4.710e-01
# Epoch 045: Train: Total=1.115e+04, Data=1.136e+00, Phys=2.233e+06, PhysData=9.419e-01 | Val: Total=6.181e+03, Data=9.511e-01, Phys=1.238e+06, PhysData=4.985e-01 | Lambda: λ1=4.702e-01, λ2=4.988e-03, λ3=4.711e-01
# Epoch 046: Train: Total=9.400e+03, Data=1.106e+00, Phys=1.883e+06, PhysData=9.423e-01 | Val: Total=5.850e+03, Data=9.111e-01, Phys=1.171e+06, PhysData=4.985e-01 | Lambda: λ1=4.703e-01, λ2=4.988e-03, λ3=4.712e-01
# Epoch 047: Train: Total=6.913e+03, Data=1.067e+00, Phys=1.384e+06, PhysData=9.417e-01 | Val: Total=8.737e+03, Data=8.832e-01, Phys=1.750e+06, PhysData=4.985e-01 | Lambda: λ1=4.704e-01, λ2=4.988e-03, λ3=4.713e-01
# Epoch 048: Train: Total=7.911e+03, Data=1.045e+00, Phys=1.585e+06, PhysData=9.417e-01 | Val: Total=6.950e+03, Data=8.725e-01, Phys=1.392e+06, PhysData=4.985e-01 | Lambda: λ1=4.705e-01, λ2=4.988e-03, λ3=4.714e-01
# Epoch 049: Train: Total=6.775e+03, Data=1.040e+00, Phys=1.357e+06, PhysData=9.426e-01 | Val: Total=4.952e+03, Data=8.714e-01, Phys=9.914e+05, PhysData=4.985e-01 | Lambda: λ1=4.706e-01, λ2=4.988e-03, λ3=4.716e-01
# Epoch 050: Train: Total=5.196e+03, Data=1.038e+00, Phys=1.040e+06, PhysData=9.425e-01 | Val: Total=4.838e+03, Data=8.719e-01, Phys=9.685e+05, PhysData=4.985e-01 | Lambda: λ1=4.708e-01, λ2=4.988e-03, λ3=4.717e-01
# Epoch 051: Train: Total=5.024e+03, Data=1.036e+00, Phys=1.006e+06, PhysData=9.416e-01 | Val: Total=3.417e+03, Data=8.706e-01, Phys=6.835e+05, PhysData=4.985e-01 | Lambda: λ1=4.709e-01, λ2=4.988e-03, λ3=4.719e-01
# Epoch 052: Train: Total=2.854e+03, Data=1.037e+00, Phys=5.706e+05, PhysData=9.420e-01 | Val: Total=1.710e+03, Data=8.702e-01, Phys=3.414e+05, PhysData=4.985e-01 | Lambda: λ1=4.711e-01, λ2=4.988e-03, λ3=4.721e-01
# Epoch 053: Train: Total=2.225e+03, Data=1.036e+00, Phys=4.446e+05, PhysData=9.418e-01 | Val: Total=1.521e+03, Data=8.716e-01, Phys=3.035e+05, PhysData=4.985e-01 | Lambda: λ1=4.714e-01, λ2=4.988e-03, λ3=4.724e-01
# Epoch 054: Train: Total=2.048e+03, Data=1.038e+00, Phys=4.092e+05, PhysData=9.422e-01 | Val: Total=2.257e+03, Data=8.712e-01, Phys=4.511e+05, PhysData=4.985e-01 | Lambda: λ1=4.718e-01, λ2=4.988e-03, λ3=4.728e-01
# Epoch 055: Train: Total=1.397e+03, Data=1.037e+00, Phys=2.785e+05, PhysData=9.423e-01 | Val: Total=9.072e+02, Data=8.711e-01, Phys=1.804e+05, PhysData=4.985e-01 | Lambda: λ1=4.723e-01, λ2=4.987e-03, λ3=4.733e-01
# Epoch 056: Train: Total=1.017e+03, Data=1.037e+00, Phys=2.023e+05, PhysData=9.419e-01 | Val: Total=2.660e+04, Data=8.717e-01, Phys=5.333e+06, PhysData=4.985e-01 | Lambda: λ1=4.728e-01, λ2=4.987e-03, λ3=4.739e-01
# Epoch 057: Train: Total=2.098e+04, Data=1.041e+00, Phys=4.205e+06, PhysData=9.425e-01 | Val: Total=1.355e+04, Data=8.739e-01, Phys=2.716e+06, PhysData=4.985e-01 | Lambda: λ1=4.734e-01, λ2=4.987e-03, λ3=4.745e-01
# Epoch 058: Train: Total=3.042e+04, Data=1.040e+00, Phys=6.098e+06, PhysData=9.423e-01 | Val: Total=1.809e+04, Data=8.761e-01, Phys=3.626e+06, PhysData=4.985e-01 | Lambda: λ1=4.736e-01, λ2=4.987e-03, λ3=4.748e-01
# Epoch 059: Train: Total=1.463e+04, Data=1.040e+00, Phys=2.931e+06, PhysData=9.417e-01 | Val: Total=1.635e+04, Data=8.770e-01, Phys=3.277e+06, PhysData=4.985e-01 | Lambda: λ1=4.737e-01, λ2=4.987e-03, λ3=4.749e-01
# Epoch 060: Train: Total=2.194e+04, Data=1.040e+00, Phys=4.397e+06, PhysData=9.424e-01 | Val: Total=2.724e+04, Data=8.735e-01, Phys=5.461e+06, PhysData=4.985e-01 | Lambda: λ1=4.738e-01, λ2=4.987e-03, λ3=4.750e-01
# Epoch 061: Train: Total=3.446e+04, Data=1.040e+00, Phys=6.908e+06, PhysData=9.421e-01 | Val: Total=3.249e+04, Data=8.744e-01, Phys=6.514e+06, PhysData=4.985e-01 | Lambda: λ1=4.739e-01, λ2=4.987e-03, λ3=4.750e-01
# Epoch 062: Train: Total=1.850e+04, Data=1.038e+00, Phys=3.708e+06, PhysData=9.421e-01 | Val: Total=1.219e+04, Data=8.726e-01, Phys=2.443e+06, PhysData=4.985e-01 | Lambda: λ1=4.739e-01, λ2=4.987e-03, λ3=4.751e-01
# Epoch 063: Train: Total=1.010e+04, Data=1.038e+00, Phys=2.023e+06, PhysData=9.423e-01 | Val: Total=1.241e+04, Data=8.729e-01, Phys=2.487e+06, PhysData=4.985e-01 | Lambda: λ1=4.739e-01, λ2=4.987e-03, λ3=4.751e-01
# Epoch 064: Train: Total=1.204e+04, Data=1.037e+00, Phys=2.414e+06, PhysData=9.418e-01 | Val: Total=1.059e+04, Data=8.719e-01, Phys=2.123e+06, PhysData=4.985e-01 | Lambda: λ1=4.740e-01, λ2=4.987e-03, λ3=4.752e-01
# Epoch 065: Train: Total=1.449e+04, Data=1.036e+00, Phys=2.903e+06, PhysData=9.415e-01 | Val: Total=1.595e+04, Data=8.708e-01, Phys=3.197e+06, PhysData=4.985e-01 | Lambda: λ1=4.741e-01, λ2=4.987e-03, λ3=4.753e-01
# Epoch 066: Train: Total=7.489e+03, Data=1.037e+00, Phys=1.500e+06, PhysData=9.424e-01 | Val: Total=6.594e+03, Data=8.706e-01, Phys=1.321e+06, PhysData=4.985e-01 | Lambda: λ1=4.741e-01, λ2=4.987e-03, λ3=4.753e-01
# Epoch 067: Train: Total=4.372e+03, Data=1.036e+00, Phys=8.752e+05, PhysData=9.420e-01 | Val: Total=2.015e+03, Data=8.707e-01, Phys=4.026e+05, PhysData=4.985e-01 | Lambda: λ1=4.742e-01, λ2=4.987e-03, λ3=4.754e-01
# Epoch 068: Train: Total=5.789e+03, Data=1.036e+00, Phys=1.159e+06, PhysData=9.417e-01 | Val: Total=2.731e+03, Data=8.708e-01, Phys=5.461e+05, PhysData=4.985e-01 | Lambda: λ1=4.742e-01, λ2=4.987e-03, λ3=4.754e-01
# Epoch 069: Train: Total=2.985e+03, Data=1.036e+00, Phys=5.971e+05, PhysData=9.420e-01 | Val: Total=2.124e+03, Data=8.705e-01, Phys=4.245e+05, PhysData=4.985e-01 | Lambda: λ1=4.742e-01, λ2=4.987e-03, λ3=4.755e-01
# Epoch 070: Train: Total=2.370e+03, Data=1.036e+00, Phys=4.738e+05, PhysData=9.418e-01 | Val: Total=1.849e+03, Data=8.704e-01, Phys=3.692e+05, PhysData=4.985e-01 | Lambda: λ1=4.743e-01, λ2=4.987e-03, λ3=4.755e-01
# Epoch 071: Train: Total=2.690e+03, Data=1.036e+00, Phys=5.378e+05, PhysData=9.419e-01 | Val: Total=1.964e+03, Data=8.703e-01, Phys=3.924e+05, PhysData=4.985e-01 | Lambda: λ1=4.744e-01, λ2=4.987e-03, λ3=4.756e-01
# Epoch 072: Train: Total=1.649e+03, Data=1.036e+00, Phys=3.292e+05, PhysData=9.425e-01 | Val: Total=1.787e+03, Data=8.702e-01, Phys=3.569e+05, PhysData=4.985e-01 | Lambda: λ1=4.745e-01, λ2=4.987e-03, λ3=4.757e-01
# Epoch 073: Train: Total=1.756e+03, Data=1.035e+00, Phys=3.506e+05, PhysData=9.414e-01 | Val: Total=2.915e+03, Data=8.702e-01, Phys=5.831e+05, PhysData=4.985e-01 | Lambda: λ1=4.746e-01, λ2=4.987e-03, λ3=4.758e-01
# Epoch 074: Train: Total=2.054e+03, Data=1.035e+00, Phys=4.104e+05, PhysData=9.412e-01 | Val: Total=2.191e+03, Data=8.701e-01, Phys=4.380e+05, PhysData=4.985e-01 | Lambda: λ1=4.747e-01, λ2=4.987e-03, λ3=4.759e-01
# Epoch 075: Train: Total=1.145e+03, Data=1.036e+00, Phys=2.281e+05, PhysData=9.418e-01 | Val: Total=7.071e+02, Data=8.702e-01, Phys=1.403e+05, PhysData=4.985e-01 | Lambda: λ1=4.748e-01, λ2=4.987e-03, λ3=4.760e-01
# Epoch 076: Train: Total=7.378e+02, Data=1.036e+00, Phys=1.464e+05, PhysData=9.424e-01 | Val: Total=5.412e+02, Data=8.702e-01, Phys=1.070e+05, PhysData=4.985e-01 | Lambda: λ1=4.748e-01, λ2=4.987e-03, λ3=4.761e-01
# Epoch 077: Train: Total=7.480e+02, Data=1.037e+00, Phys=1.484e+05, PhysData=9.423e-01 | Val: Total=6.381e+02, Data=8.701e-01, Phys=1.265e+05, PhysData=4.985e-01 | Lambda: λ1=4.749e-01, λ2=4.987e-03, λ3=4.761e-01
# Epoch 078: Train: Total=4.924e+02, Data=1.036e+00, Phys=9.720e+04, PhysData=9.419e-01 | Val: Total=4.443e+02, Data=8.701e-01, Phys=8.761e+04, PhysData=4.985e-01 | Lambda: λ1=4.750e-01, λ2=4.987e-03, λ3=4.762e-01
# Epoch 079: Train: Total=5.663e+02, Data=1.037e+00, Phys=1.120e+05, PhysData=9.428e-01 | Val: Total=5.783e+02, Data=8.702e-01, Phys=1.145e+05, PhysData=4.985e-01 | Lambda: λ1=4.750e-01, λ2=4.987e-03, λ3=4.763e-01
# Epoch 080: Train: Total=4.732e+02, Data=1.036e+00, Phys=9.335e+04, PhysData=9.421e-01 | Val: Total=3.848e+02, Data=8.701e-01, Phys=7.567e+04, PhysData=4.985e-01 | Lambda: λ1=4.751e-01, λ2=4.987e-03, λ3=4.764e-01
# Epoch 081: Train: Total=4.527e+02, Data=1.036e+00, Phys=8.924e+04, PhysData=9.418e-01 | Val: Total=3.133e+02, Data=8.701e-01, Phys=6.133e+04, PhysData=4.985e-01 | Lambda: λ1=4.752e-01, λ2=4.987e-03, λ3=4.765e-01
# Epoch 082: Train: Total=4.816e+02, Data=1.037e+00, Phys=9.503e+04, PhysData=9.425e-01 | Val: Total=3.515e+02, Data=8.701e-01, Phys=6.900e+04, PhysData=4.985e-01 | Lambda: λ1=4.753e-01, λ2=4.987e-03, λ3=4.766e-01
# Epoch 083: Train: Total=3.027e+02, Data=1.036e+00, Phys=5.916e+04, PhysData=9.423e-01 | Val: Total=2.341e+02, Data=8.701e-01, Phys=4.545e+04, PhysData=4.985e-01 | Lambda: λ1=4.754e-01, λ2=4.986e-03, λ3=4.767e-01
# Epoch 084: Train: Total=4.806e+02, Data=1.036e+00, Phys=9.483e+04, PhysData=9.420e-01 | Val: Total=3.373e+02, Data=8.701e-01, Phys=6.614e+04, PhysData=4.985e-01 | Lambda: λ1=4.755e-01, λ2=4.986e-03, λ3=4.768e-01
# Epoch 085: Train: Total=4.409e+02, Data=1.035e+00, Phys=8.687e+04, PhysData=9.416e-01 | Val: Total=3.693e+02, Data=8.702e-01, Phys=7.256e+04, PhysData=4.985e-01 | Lambda: λ1=4.756e-01, λ2=4.986e-03, λ3=4.769e-01
# Epoch 086: Train: Total=2.737e+02, Data=1.036e+00, Phys=5.335e+04, PhysData=9.422e-01 | Val: Total=3.305e+02, Data=8.701e-01, Phys=6.478e+04, PhysData=4.985e-01 | Lambda: λ1=4.757e-01, λ2=4.986e-03, λ3=4.769e-01
# Epoch 087: Train: Total=3.011e+02, Data=1.036e+00, Phys=5.884e+04, PhysData=9.420e-01 | Val: Total=3.986e+02, Data=8.702e-01, Phys=7.844e+04, PhysData=4.985e-01 | Lambda: λ1=4.758e-01, λ2=4.986e-03, λ3=4.770e-01
# Epoch 088: Train: Total=2.823e+02, Data=1.037e+00, Phys=5.507e+04, PhysData=9.423e-01 | Val: Total=3.779e+02, Data=8.701e-01, Phys=7.429e+04, PhysData=4.985e-01 | Lambda: λ1=4.758e-01, λ2=4.986e-03, λ3=4.771e-01
# Epoch 089: Train: Total=2.532e+02, Data=1.036e+00, Phys=4.923e+04, PhysData=9.420e-01 | Val: Total=2.248e+02, Data=8.701e-01, Phys=4.358e+04, PhysData=4.985e-01 | Lambda: λ1=4.759e-01, λ2=4.986e-03, λ3=4.772e-01
# Epoch 090: Train: Total=4.591e+02, Data=1.036e+00, Phys=9.052e+04, PhysData=9.423e-01 | Val: Total=2.512e+02, Data=8.701e-01, Phys=4.889e+04, PhysData=4.985e-01 | Lambda: λ1=4.760e-01, λ2=4.986e-03, λ3=4.773e-01
# Epoch 091: Train: Total=2.446e+02, Data=1.036e+00, Phys=4.750e+04, PhysData=9.422e-01 | Val: Total=3.083e+02, Data=8.701e-01, Phys=6.034e+04, PhysData=4.985e-01 | Lambda: λ1=4.761e-01, λ2=4.986e-03, λ3=4.774e-01
# Epoch 092: Train: Total=3.163e+02, Data=1.036e+00, Phys=6.189e+04, PhysData=9.422e-01 | Val: Total=2.754e+02, Data=8.702e-01, Phys=5.375e+04, PhysData=4.985e-01 | Lambda: λ1=4.762e-01, λ2=4.986e-03, λ3=4.775e-01
# Epoch 093: Train: Total=2.521e+02, Data=1.036e+00, Phys=4.901e+04, PhysData=9.418e-01 | Val: Total=2.968e+02, Data=8.701e-01, Phys=5.803e+04, PhysData=4.985e-01 | Lambda: λ1=4.763e-01, λ2=4.986e-03, λ3=4.776e-01
# Epoch 094: Train: Total=2.133e+02, Data=1.035e+00, Phys=4.123e+04, PhysData=9.415e-01 | Val: Total=1.809e+02, Data=8.701e-01, Phys=3.479e+04, PhysData=4.985e-01 | Lambda: λ1=4.764e-01, λ2=4.986e-03, λ3=4.777e-01
# Epoch 095: Train: Total=2.278e+02, Data=1.035e+00, Phys=4.413e+04, PhysData=9.414e-01 | Val: Total=2.954e+02, Data=8.701e-01, Phys=5.776e+04, PhysData=4.985e-01 | Lambda: λ1=4.765e-01, λ2=4.986e-03, λ3=4.778e-01
# Epoch 096: Train: Total=1.946e+02, Data=1.036e+00, Phys=3.748e+04, PhysData=9.424e-01 | Val: Total=1.771e+02, Data=8.701e-01, Phys=3.402e+04, PhysData=4.985e-01 | Lambda: λ1=4.766e-01, λ2=4.986e-03, λ3=4.780e-01
# Epoch 097: Train: Total=1.748e+02, Data=1.036e+00, Phys=3.351e+04, PhysData=9.423e-01 | Val: Total=2.526e+02, Data=8.702e-01, Phys=4.916e+04, PhysData=4.985e-01 | Lambda: λ1=4.767e-01, λ2=4.986e-03, λ3=4.781e-01
# Epoch 098: Train: Total=1.901e+02, Data=1.036e+00, Phys=3.658e+04, PhysData=9.418e-01 | Val: Total=2.223e+02, Data=8.701e-01, Phys=4.308e+04, PhysData=4.985e-01 | Lambda: λ1=4.769e-01, λ2=4.986e-03, λ3=4.782e-01
# Epoch 099: Train: Total=1.949e+02, Data=1.035e+00, Phys=3.754e+04, PhysData=9.416e-01 | Val: Total=1.345e+02, Data=8.701e-01, Phys=2.548e+04, PhysData=4.985e-01 | Lambda: λ1=4.770e-01, λ2=4.986e-03, λ3=4.783e-01
# Epoch 100: Train: Total=2.009e+02, Data=1.036e+00, Phys=3.874e+04, PhysData=9.421e-01 | Val: Total=4.422e+02, Data=8.701e-01, Phys=8.720e+04, PhysData=4.985e-01 | Lambda: λ1=4.771e-01, λ2=4.986e-03, λ3=4.784e-01
# Epoch 101: Train: Total=2.548e+02, Data=1.036e+00, Phys=4.956e+04, PhysData=9.423e-01 | Val: Total=3.746e+02, Data=8.701e-01, Phys=7.363e+04, PhysData=4.985e-01 | Lambda: λ1=4.772e-01, λ2=4.986e-03, λ3=4.785e-01
# Epoch 102: Train: Total=2.670e+02, Data=1.036e+00, Phys=5.199e+04, PhysData=9.417e-01 | Val: Total=1.991e+02, Data=8.701e-01, Phys=3.845e+04, PhysData=4.985e-01 | Lambda: λ1=4.772e-01, λ2=4.986e-03, λ3=4.786e-01
# Epoch 103: Train: Total=1.895e+02, Data=1.037e+00, Phys=3.646e+04, PhysData=9.426e-01 | Val: Total=3.331e+02, Data=8.702e-01, Phys=6.531e+04, PhysData=4.985e-01 | Lambda: λ1=4.773e-01, λ2=4.986e-03, λ3=4.787e-01
# Epoch 104: Train: Total=2.336e+02, Data=1.036e+00, Phys=4.530e+04, PhysData=9.418e-01 | Val: Total=1.835e+02, Data=8.702e-01, Phys=3.531e+04, PhysData=4.985e-01 | Lambda: λ1=4.774e-01, λ2=4.986e-03, λ3=4.788e-01
# Epoch 105: Train: Total=1.523e+02, Data=1.037e+00, Phys=2.900e+04, PhysData=9.429e-01 | Val: Total=1.218e+02, Data=8.702e-01, Phys=2.294e+04, PhysData=4.985e-01 | Lambda: λ1=4.775e-01, λ2=4.986e-03, λ3=4.788e-01
# Epoch 106: Train: Total=2.316e+02, Data=1.036e+00, Phys=4.489e+04, PhysData=9.419e-01 | Val: Total=2.857e+02, Data=8.701e-01, Phys=5.580e+04, PhysData=4.985e-01 | Lambda: λ1=4.776e-01, λ2=4.986e-03, λ3=4.789e-01
# Epoch 107: Train: Total=1.696e+02, Data=1.036e+00, Phys=3.246e+04, PhysData=9.421e-01 | Val: Total=1.341e+02, Data=8.701e-01, Phys=2.540e+04, PhysData=4.985e-01 | Lambda: λ1=4.777e-01, λ2=4.986e-03, λ3=4.790e-01
# Epoch 108: Train: Total=1.684e+02, Data=1.037e+00, Phys=3.223e+04, PhysData=9.427e-01 | Val: Total=2.618e+02, Data=8.702e-01, Phys=5.102e+04, PhysData=4.985e-01 | Lambda: λ1=4.778e-01, λ2=4.986e-03, λ3=4.791e-01
# Epoch 109: Train: Total=1.704e+02, Data=1.036e+00, Phys=3.263e+04, PhysData=9.422e-01 | Val: Total=1.603e+02, Data=8.702e-01, Phys=3.066e+04, PhysData=4.985e-01 | Lambda: λ1=4.779e-01, λ2=4.986e-03, λ3=4.792e-01
# Epoch 110: Train: Total=1.493e+02, Data=1.037e+00, Phys=2.839e+04, PhysData=9.427e-01 | Val: Total=1.274e+02, Data=8.702e-01, Phys=2.407e+04, PhysData=4.985e-01 | Lambda: λ1=4.780e-01, λ2=4.986e-03, λ3=4.793e-01
# Epoch 111: Train: Total=1.439e+02, Data=1.036e+00, Phys=2.730e+04, PhysData=9.419e-01 | Val: Total=1.410e+02, Data=8.701e-01, Phys=2.678e+04, PhysData=4.985e-01 | Lambda: λ1=4.781e-01, λ2=4.986e-03, λ3=4.794e-01
# Epoch 112: Train: Total=1.798e+02, Data=1.037e+00, Phys=3.450e+04, PhysData=9.429e-01 | Val: Total=1.342e+02, Data=8.701e-01, Phys=2.542e+04, PhysData=4.985e-01 | Lambda: λ1=4.782e-01, λ2=4.986e-03, λ3=4.795e-01
# Epoch 113: Train: Total=1.389e+02, Data=1.036e+00, Phys=2.632e+04, PhysData=9.418e-01 | Val: Total=1.104e+02, Data=8.701e-01, Phys=2.065e+04, PhysData=4.985e-01 | Lambda: λ1=4.783e-01, λ2=4.986e-03, λ3=4.796e-01
# Epoch 114: Train: Total=5.038e+02, Data=1.037e+00, Phys=9.949e+04, PhysData=9.425e-01 | Val: Total=3.293e+02, Data=8.701e-01, Phys=6.455e+04, PhysData=4.985e-01 | Lambda: λ1=4.784e-01, λ2=4.986e-03, λ3=4.797e-01
# Epoch 115: Train: Total=1.940e+02, Data=1.037e+00, Phys=3.736e+04, PhysData=9.425e-01 | Val: Total=1.270e+02, Data=8.701e-01, Phys=2.397e+04, PhysData=4.985e-01 | Lambda: λ1=4.784e-01, λ2=4.986e-03, λ3=4.798e-01
# Epoch 116: Train: Total=1.398e+02, Data=1.036e+00, Phys=2.649e+04, PhysData=9.420e-01 | Val: Total=2.522e+02, Data=8.701e-01, Phys=4.908e+04, PhysData=4.985e-01 | Lambda: λ1=4.785e-01, λ2=4.986e-03, λ3=4.799e-01
# Epoch 117: Train: Total=4.663e+02, Data=1.035e+00, Phys=9.196e+04, PhysData=9.410e-01 | Val: Total=2.928e+02, Data=8.701e-01, Phys=5.724e+04, PhysData=4.985e-01 | Lambda: λ1=4.786e-01, λ2=4.986e-03, λ3=4.800e-01
# Epoch 118: Train: Total=2.261e+02, Data=1.036e+00, Phys=4.380e+04, PhysData=9.418e-01 | Val: Total=1.360e+02, Data=8.702e-01, Phys=2.578e+04, PhysData=4.985e-01 | Lambda: λ1=4.787e-01, λ2=4.986e-03, λ3=4.800e-01
# Epoch 119: Train: Total=2.507e+02, Data=1.036e+00, Phys=4.872e+04, PhysData=9.418e-01 | Val: Total=1.613e+02, Data=8.701e-01, Phys=3.087e+04, PhysData=4.985e-01 | Lambda: λ1=4.787e-01, λ2=4.986e-03, λ3=4.801e-01
# Epoch 120: Train: Total=1.415e+02, Data=1.037e+00, Phys=2.683e+04, PhysData=9.427e-01 | Val: Total=1.239e+02, Data=8.701e-01, Phys=2.335e+04, PhysData=4.985e-01 | Lambda: λ1=4.788e-01, λ2=4.986e-03, λ3=4.801e-01
#
# Total training time: 6.57 minutes (394.50 seconds)

# %%
def plot_loss_curves(tr_tot, tr_data, tr_phys, tr_physdata,
                     va_tot, va_data, va_phys, va_physdata,
                     epoch_range: tuple[int, int] | None = None,
                     save_path: str | None = None) -> None:
    """Plot 2x2 training/validation loss curves.

    Args:
        epoch_range: (start, end) inclusive 1-indexed epoch range. None shows all.
    """
    import matplotlib.pyplot as plt
    import matplotlib as mpl

    mpl.rcParams.update({
        'font.family': 'sans-serif',
        'font.sans-serif': ['Inter', 'Helvetica', 'Arial'],
        'axes.spines.top': True,
        'axes.spines.right': True,
        'axes.grid': False,
        'axes.edgecolor': '#2C2C2A',
        'axes.labelcolor': '#212529',
        'xtick.color': '#2C2C2A',
        'ytick.color': '#2C2C2A',
        'figure.dpi': 150,
        'savefig.dpi': 300,
        'savefig.bbox': 'tight',
    })

    if epoch_range is not None:
        s, e = epoch_range[0] - 1, epoch_range[1]
    else:
        s, e = 0, len(tr_tot)

    train_color = '#2563EB'
    val_color = '#D97706'

    fig, axes = plt.subplots(2, 2, figsize=(12, 8))
    titles = ['Total Loss (MSE)', 'Data Loss (MSE)', 'Physics Loss (MSE)', 'Phys-Data Loss (MSE)']
    train_data = [tr_tot[s:e], tr_data[s:e], tr_phys[s:e], tr_physdata[s:e]]
    val_data = [va_tot[s:e], va_data[s:e], va_phys[s:e], va_physdata[s:e]]

    for ax, title, tr, va in zip(axes.flat, titles, train_data, val_data):
        epochs = range(s + 1, s + len(tr) + 1)
        ax.plot(epochs, tr, color=train_color, linewidth=1.2, label='Train')
        ax.plot(epochs, va, color=val_color, linewidth=1.2, label='Val')
        ax.set_title(title, fontsize=13, fontweight=500, color='#2C2C2A')
        ax.set_xlabel('Iteration', fontsize=12)
        ax.set_ylabel('MSE', fontsize=12)
        ax.tick_params(labelsize=11)
        ax.spines[:].set_linewidth(0.8)
        ax.legend(fontsize=10, frameon=True, edgecolor='#B4B2A9', facecolor='white')

    fig.suptitle('SciNoNet (Case I)', fontsize=16, fontweight=500, y=1.01, color='#212529')
    plt.tight_layout()
    if save_path:
        fig.savefig(save_path, format='jpeg', dpi=300, bbox_inches='tight', facecolor='white')
        print(f'Saved: {save_path}')
    plt.show()

# %%
plot_loss_curves(tr_tot, tr_data, tr_phys, tr_physdata,
                 va_tot, va_data, va_phys, va_physdata,
                 epoch_range=(250, 500))

# %%
plot_loss_curves(
    tr_tot, tr_data, tr_phys, tr_physdata,
    va_tot, va_data, va_phys, va_physdata,
    save_path='./loss_curves.jpg'
)
# Out:
# Saved: ./loss_curves.jpg

# %%
def visualize_full_reconstruction(model: torch.nn.Module,
                                  X: torch.Tensor,
                                  full_signal_df: pd.DataFrame,
                                  means: pd.Series,
                                  stds_repl: pd.Series,
                                  point_index: int,
                                  component: str = 'u',
                                  save_path: str | None = None,
                                  figsize: tuple[float, float] = (14, 4)) -> None:
    """Predict full 6001-timestep signal and overlay full ground truth."""
    import matplotlib.pyplot as plt
    import matplotlib as mpl

    mpl.rcParams.update({
        'font.family': 'sans-serif',
        'font.sans-serif': ['Inter', 'Helvetica', 'Arial'],
        'axes.spines.top': True,
        'axes.spines.right': True,
        'axes.grid': False,
        'axes.edgecolor': '#2C2C2A',
        'axes.labelcolor': '#212529',
        'xtick.color': '#2C2C2A',
        'ytick.color': '#2C2C2A',
        'figure.dpi': 150,
        'savefig.dpi': 300,
        'savefig.bbox': 'tight',
    })

    comp_out = {'u': 0, 'v': 1, 'w': 2}[component]
    dt = 1e-8

    unique_xyz_std = torch.unique(X[:, :3], dim=0)
    xyz_std = unique_xyz_std[point_index]
    xyz_phys = xyz_std.numpy() * stds_repl[['x', 'y', 'z']].values + means[['x', 'y', 'z']].values

    # === Full 6001-step prediction ===
    t_full = np.arange(1, 6002) * dt
    t_full_std = (t_full - means['t']) / stds_repl['t']
    X_full = torch.zeros(6001, 4, dtype=torch.float64)
    X_full[:, 0] = xyz_std[0]
    X_full[:, 1] = xyz_std[1]
    X_full[:, 2] = xyz_std[2]
    X_full[:, 3] = torch.tensor(t_full_std, dtype=torch.float64)

    model.eval()
    with torch.no_grad():
        mag_out, sign_out, _, _ = model(X_full.to(next(model.parameters()).device))
        y_pred_std = reconstruct(mag_out, sign_out).cpu().numpy()

    pred_signal = y_pred_std[:, comp_out] * stds_repl[['u', 'v', 'w']].values[comp_out] \
                  + means[['u', 'v', 'w']].values[comp_out]

    # === Ground truth from full signal dataset ===
    mask = (np.abs(full_signal_df['x'].values - xyz_phys[0]) < 0.1) & \
           (np.abs(full_signal_df['y'].values - xyz_phys[1]) < 0.1)
    gt_grp = full_signal_df[mask].sort_values('t').reset_index(drop=True)
    gt_signal = gt_grp[component].values
    gt_indices = np.round(gt_grp['t'].values / dt - 1).astype(int)

    # === Plot ===
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    ax.plot(gt_indices, gt_signal, color='#212529', linewidth=1.2, label='Ground truth')
    ax.plot(np.arange(6001), pred_signal, color='#DC2626', linewidth=1.5,
            linestyle='--', alpha=0.85, label='Predicted (full)')

    ax.set_xlabel('Timestep index', fontsize=14, fontweight=500)
    ax.set_ylabel(component, fontsize=14, fontweight=500)
    ax.tick_params(labelsize=12, width=1.0, length=4)
    ax.spines[:].set_linewidth(0.8)

    coord_str = f'(x={xyz_phys[0]:.1f}, y={xyz_phys[1]:.1f})'
    ax.set_title(coord_str, fontsize=13, fontweight=500, color='#2C2C2A', pad=10)
    ax.legend(fontsize=11, loc='upper center', ncol=2, frameon=True,
              edgecolor='#B4B2A9', facecolor='white', bbox_to_anchor=(0.5, 1.0))

    plt.tight_layout()
    if save_path:
        fig.savefig(save_path, format='jpeg', dpi=300, bbox_inches='tight', facecolor='white')
        print(f'Saved: {save_path}')
    plt.show()

# %%
df_full_signal = pd.read_csv('dataset_50_spatialpoints_fullsignal_mixed_rec_neighbor_50inrange.csv')
visualize_full_reconstruction(
    model, X_train, df_full_signal, means, stds_repl,
    point_index= 0, component='w', save_path='./recon_point0_u.jpg'
)
# Out:
# Saved: ./recon_point0_u.jpg

# %%
visualize_full_reconstruction(
    model, X_train, df_full_signal, means, stds_repl,
    point_index= 10, component='w', save_path='./recon_point0_u.jpg'
)
# Out:
# Saved: ./recon_point0_u.jpg

# %%
ffn = model.module.ffn if isinstance(model, nn.DataParallel) else model.ffn
a = ffn.a.detach().cpu()
B = ffn.B.detach().cpu()

for name, tensor in [("a", a), ("B", B)]:
    print(f"\n{name} shape: {tensor.shape}")
    for dim in range(tensor.shape[0]):
        row = tensor[dim]
        print(f"  {['x','y','z','t'][dim]}: [{row.min():.4e}, {row.max():.4e}]")
# Out:
# a shape: torch.Size([4, 32])
#   x: [9.4885e-01, 1.0296e+00]
#   y: [9.2823e-01, 1.0353e+00]
#   z: [1.0000e+00, 1.0000e+00]
#   t: [9.7407e-01, 1.0374e+00]
#
# B shape: torch.Size([4, 32])
#   x: [8.7532e-02, 1.9066e+00]
#   y: [2.5603e-02, 1.9535e+00]
#   z: [1.0000e+00, 1.0000e+00]
#   t: [1.2207e+04, 1.9690e+05]
